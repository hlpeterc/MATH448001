# %% [markdown]
# # Project 0
#
# Complete each of the below exercises. You should write your code only in between
#
#   ########## Your Code goes here #############
#
#   #your code
#
#   #######################################
#
# Do not change any other code in the given functions. You can create new code cells to try things however before you submit the project please delete them.
#
# You are provided test functions for some of the exercises. In order to be able to run the tests you should run the code cell below everytime you open this notebook or reset the runtime.

# %%
import os 

if not os.path.isdir('MATH448001'):
    # !git clone https://github.com/CihanSoylu/MATH448001.git

from MATH448001.project_tests import project_0_tests
# Out:
# Cloning into 'MATH448001'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 82 (delta 46), reused 60 (delta 24), pack-reused 0
# Unpacking objects: 100% (82/82), done.

# %% [markdown]
# ## Exercise 1
# Print 'Hello world!' using `print()` function in the following code cell.

# %%
############ Your code goes here ##################

###################################################

# %% [markdown]
# Expected output:
#
#
# > Hello world!

# %% [markdown]
# ## Exercise 2
# Create variable named 'var' with value 1. And print the varible using `print()` function.

# %%
############ Your code goes here ##################

###################################################

# %% [markdown]
# Expected output:
#
#
# > 1

# %% [markdown]
# ## Exercise 3
# Create a variable named 'name' with value your name as a string. And print this variable.

# %%
############ Your code goes here ##################

###################################################

# %% [markdown]
# ## Exercise 4
# Import the 'math' library via `import math` and print the value of $\pi$ and $e$. You can access these values via `math.pi` and `math.e`.

# %%
############ Your code goes here ##################

###################################################

# %% [markdown]
# Expected output:
#
# > 3.141592653589793 2.718281828459045

# %% [markdown]
# ## Exercise 5
# import the 'numpy' library with alias 'np' via `import numpy as np` and print the values of $\pi$ and $e$ from numpy.

# %%
############ Your code goes here ##################

###################################################

# %% [markdown]
# Expected output:
#
#
# > 3.141592653589793 2.718281828459045

# %% [markdown]
# ## Exercise 6
# Perform the following computation in the code cell below using numpy library.
# $$
# \frac{1}{2\pi}e^{-3/2}
# $$

# %%
############ Your code goes here ##################

###################################################

# %% [markdown]
# Expected output:
#
#
# > 0.035512267940508845

# %% [markdown]
# ## Exercise 7
# Implement the square function $f(x) = x^2$. Name your function 'square_of'. Note that in python powers are taken by `**`. For example $3^2$ would be calculated in python as `3**2`.

# %%
############ Your code goes here ##################

###################################################

# %%
project_0_tests.test_square_function(square_of)

# %% [markdown]
# ## Exercise 8
# Implement a function named 'my_name_is' that takes a string argument named 'name' with default value 'Jeff' and returns the following string:
#
# 'My name is ...'
#
# with ... replaced with the name argument.

# %%
############ Your code goes here ##################

###################################################

# %%
my_name_is()

# %% [markdown]
# Expected output:
#
#
# > 'My name is Jeff'

# %%
my_name_is('Indy')

# %% [markdown]
# Expected output:
#
#
# > My name is Indy

# %% [markdown]
# ## Exercise 9
# Implement the following function of two variables $\mu$ and $\sigma$.
# $$
# p(x) = \frac{1}{\sqrt{2\pi\sigma^2}}e^{-\frac{(x-\mu)^2}{2\sigma^2}}
# $$
# This is the probability density function of the normal distribution with mean $\mu$ and standard deviation $\sigma$. Name the function 'normal_pdf'.

# %%
import numpy as np

def normal_pdf(mu, sigma, x):
    ############ Your code goes here ##################

    ###################################################

# %%
project_0_tests.test_normal_pdf(normal_pdf)

# %% [markdown]
# ## Exercise 10
# Implement a function named `is_even` that takes an integer as an argument and returns True if its argument is even and False otherwise.
#
# Hint: `%` serves as mod in python.

# %%
def is_even(x):
    ############ Your code goes here ##################

    ###################################################

# %%
project_0_tests.test_is_even(is_even)

# %% [markdown]
# ## Exercise 11
# Write a `for` loop that loops over all numbers 1 to 20 and prints the following for each number:
# 'Square of x is x^2'
# where x is replaced by the number and x^2 is replaced by the square of the number for each.

# %%
############ Your code goes here ##################

###################################################

# %% [markdown]
# Expected output:
#
# ```
# Square of 1 is 1
# Square of 2 is 4
# Square of 3 is 9
# Square of 4 is 16
# Square of 5 is 25
# Square of 6 is 36
# Square of 7 is 49
# Square of 8 is 64
# Square of 9 is 81
# Square of 10 is 100
# Square of 11 is 121
# Square of 12 is 144
# Square of 13 is 169
# Square of 14 is 196
# Square of 15 is 225
# Square of 16 is 256
# Square of 17 is 289
# Square of 18 is 324
# Square of 19 is 361
# Square of 20 is 400
# ```

# %% [markdown]
# ## Exercise 12
# Implement a function that takes a list of numbers as its argument and return the sum of the squares of the numbers in the list. Name your function 'sum_of_squares'.

# %%
def sum_of_squares(lst):
    ############ Your code goes here ##################
        
    ###################################################

# %%
project_0_tests.test_sum_of_squares(sum_of_squares)

# %% [markdown]
# ## Exercise 13
# Implement a function that approximates $e^x$ using the Taylor series
# $$ e^x = \displaystyle\sum_{k=0}^\infty \frac{x^k}{k!}$$
# for all $x$. Your function will take two arguments:
#
#  - $x$: the point at which we are approximating $e^x$
#  -$n$: the order of the Taylor polynomial for the approximation:
#
#  $$
#  e^x \approx \displaystyle\sum_{k=0}^n \frac{x^k}{k!}
#  $$
#
#  You can use `math.factorial()` function from the math library to compute $k!$.
#
#  Remember that in Python the syntax for the powers is as follows: $x^k$ is written as `x**k`

# %%
import math

def taylor_exp(x, n):
  
    ########## Your Code goes here #############

    ############################################

# %%
project_0_tests.test_taylor_exp(taylor_exp)

# %% [markdown]
# ## Exercise 14
# Implement a function that determines if a given integer is prime or not. Your function has one integer argument `n` and returns True if `n` is prime and False otherwise. A basic algorithm goes as follows:
#
#  - Loop over the numbers starting from 2 to `n-1` and check if `n` is divisible by these numbers.
#  - if you find a number that divides `n` return False, otherwise return True.
#
#  This algorithm works however it involves unnecessary checks and so it can be made faster. Can you think of a faster way?

# %%
def is_prime(n):
 
    ########## Your Code goes here #############
  
    ############################################

# %%
project_0_tests.test_is_prime(is_prime)

# %%
is_prime(7)

# %% [markdown]
# Expected output:
#
# ```True```

# %%
is_prime(12)

# %% [markdown]
# Expected output:
#
# ```False```

# %%
is_prime(1001)

# %% [markdown]
# Expected output:
#
# ```False```

# %%
is_prime(2147483647)

# %% [markdown]
# Expected output:
#
# ```True```

# %% [markdown]
# ## Exercise 15
#
# Implement a function named 'factorize' that takes a positive integer as its argument and returns a list of primes in its prime factorization. For example, `factorize(12)` will return `[2,2,3]`.

# %%
def factorize(n):
    ########## Your Code goes here #############

    ############################################

# %%
project_0_tests.test_factorize(factorize)

# %%
factorize(12)

# %% [markdown]
# Expected output:
#
# ```[2, 2, 3]```

# %%
factorize(142135215)

# %% [markdown]
# Expected output:
#
# ```[3, 5, 17, 547, 1019]```

# %%
factorize(5)

# %% [markdown]
# Expected output:
#
# ```[5]```
