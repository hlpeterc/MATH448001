# %% [markdown]
# # Project 4
#
# In this project you will implement Feedforward Densely connected neural networks using Tensorflow high level API, tf.keras. You will also apply PCA on a dataset and visualize the 2D and 3D projections.

# %%
import os
# %tensorflow_version 2.x 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import tensorflow as tf

if not os.path.isdir('MATH448001'):
    # !git clone https://github.com/CihanSoylu/MATH448001.git

from MATH448001.project_utils import project_2_utils, project_3_utils, project_4_utils

# %% [markdown]
# # Exercise 1 (20 points)
#
# Create a neural network to model the auto-mpg regression problem. For details on the dataset see Project 2.
#
# Let's first load the data.

# %%
df, x_train, y_train, x_val, y_val = project_2_utils.load_auto_mpg_data()

# %%
df.head()

# %%
x_train.shape

# %% [markdown]
# Implement a function that returns a `tf.keras.Sequential` model appropriate for this problem. You can add hidden layers to your model as you wish.

# %%
def create_regression_model(input_shape):

    ########## Your Code goes here #############


    #############################################

    return model

# %% [markdown]
# Create a model using the above function and complie with SGD optimizer, mean squared error loss function and root mean squared error metric.

# %%
tf.keras.backend.clear_session()

########## Your Code goes here #############

# TODO: Create the model
model = 

# TODO: Create the optimizer
opt = 

# TODO: Create the loss function
loss = 

# TODO: Create root mean squared error metric. 
rmse = 

# TODO: Compile the model


#############################################

# %% [markdown]
# Train your model by calling `model.fit()` with the appropriate arguments. Can you get a `val_loss` that is less than 5. Compare your results with Project 3.

# %%
########## Your Code goes here #############

history = model.fit()

#############################################

# %%
pd.DataFrame(history.history)[['loss', 'val_loss']].plot()

# %% [markdown]
# # Exercise 2 (20 points)
#
# Create a neural network to model the Breast Cancer diagnosis problem. For details on the dataset see Project 3 notebook.
#
# First load the data.

# %%
x_train, x_val, y_train, y_val = project_2_utils.load_data(n_features = 30)

# %%
x_train.shape

# %% [markdown]
# Implement a function that returns a `tf.keras.Sequential` model appropriate for this problem. You can add hidden layers to your model as you wish.

# %%
def create_binary_classification_model(input_shape):

    ########## Your Code goes here #############


    #############################################

    return model

# %% [markdown]
# Create a model using the above function and complie with SGD optimizer, binary crossentropy loss function and accuracy metric.

# %%
tf.keras.backend.clear_session()

########## Your Code goes here #############

# TODO: Create the model
model = 

# TODO: Create the optimizer
opt = 

# TODO: Create the loss function
loss = 
# TODO: Create a binary accuracy metric
metrics = 

# TODO: Compile the model


#############################################

# %% [markdown]
# Train your model. Can you get a `val_binary_accuracy` that is greater than 96%? Compare your results with Project 3.

# %%
########## Your Code goes here #############

history = 

#############################################

# %%
pd.DataFrame(history.history).plot()

# %% [markdown]
# # Exercise 3 (30 points)
#
# In this exercise you will implement a neural network to solve a multi class classification problem. The dataset we will be using is called Fashin-MNIST and it consists of 28x28 grayscale images of clothing. More info on the dataset is [here](https://github.com/zalandoresearch/fashion-mnist).
#
# Let's load the data:

# %%
x_train, y_train, x_val, y_val = project_4_utils.load_data()

# %%
x_train.shape

# %% [markdown]
# The class names with the corresponding labels:
#
# | Label | Description |
# | --- | --- |
# | 0 | T-shirt/top |
# | 1 | Trouser |
# | 2 | Pullover |
# | 3 | Dress |
# | 4 | Coat |
# | 5 | Sandal |
# | 6 | Shirt |
# | 7 | Sneaker |
# | 8 | Bag |
# | 9 | Ankle boot |

# %%
project_4_utils.plot_data(x_train[:5], y_train[:5])

# %% [markdown]
# Implement a function that returns a `tf.keras.Sequential` model appropriate for this problem. You can add hidden layers to your model as you wish.

# %%
def create_multi_classification_model(input_shape):

    ########## Your Code goes here #############


    #############################################

    return model

# %% [markdown]
# Create a model using the above function and complie with SGD optimizer, binary crossentropy loss function and accuracy metric.

# %%
tf.keras.backend.clear_session()

########## Your Code goes here #############

# TODO: Create the model
model = 

# TODO: Create the optimizer
opt = 

# TODO: Create the loss function
loss = 

# TODO: Create a binary accuracy metric
metrics = 

# TODO: Compile the model


#############################################

# %% [markdown]
# Train your model. Can you get a `val_sparse_categorical_accuracy` that is greater than 87% in 20 epochs?

# %%
########## Your Code goes here #############

history = 

#############################################

# %%
pd.DataFrame(history.history).plot()

# %% [markdown]
# # Exercise 4 (30 points)
#
# In this exercise, you will be applying PCA on the Breast Cancer dataset. Let's load the data first:

# %%
x_train, x_val, y_train, y_val = project_2_utils.load_data(n_features = 30)

# %% [markdown]
# In this case the design matrix for the data is `x_train` and it has shape (398, 30), so each example is 30 dimensional.

# %%
x_train.shape

# %% [markdown]
# Implement a function which takes the design matrix X for the data where each row is a single example and return the singular vectors for X as a matrix. In the case of the Breast Cancer dataset, there will be 30 singular vectors. The function will return a matrix with columns consisting of the singular vectors. (Hint: This is the matrix V in the singular value decomposition of X)

# %%
def singular_vectors(X):

    ########## Your Code goes here #############


    #############################################

# %% [markdown]
# Now use this function to find the first 2 singular vectors of `x_train` and project the data `x_train` onto the subspace spanned by these 2 vectors. Also project the validation data `x_val` onto this same subspace (use the same 2 singular vectors of `x_train`).

# %%
########## Your Code goes here #############

x_train_reduced_2D = 
x_val_reduced_2D = 

#############################################

# %%
x_train_reduced_2D.shape

# %% [markdown]
# Expected output:
#
# ```
# (398, 2)
# ```

# %% [markdown]
# The following code cell plots this 2D projection.

# %%
plt.scatter(x_train_reduced_2D[:,0], x_train_reduced_2D[:,1], c = y_train.squeeze())

# %% [markdown]
# Do the same with the first 3 singular vectors.

# %%
########## Your Code goes here #############

x_train_reduced_3D = 

#############################################

# %%
x_train_reduced_3D.shape

# %% [markdown]
# The following code cell plots this 3D projection.

# %%
import plotly.graph_objects as go

x = x_train_reduced_3D[:,0]
y = x_train_reduced_3D[:,1]
z = x_train_reduced_3D[:,2]

fig = go.Figure(data=[go.Scatter3d(
    x=x,
    y=y,
    z=z,
    mode='markers+text',
    marker=dict(
        size=8,
        color=y_train.squeeze(),                 
        opacity=0.8
    )
)])

# tight layout
fig.update_layout(margin=dict(l=0, r=0, b=0, t=0))
fig.show()

# %% [markdown]
# Train another binary classification model on the 2D projection `x_train_reduced_2D` you obtained above. In other words repeat Exercise 2 using the 2D reduced dataset `x_train_reduced_2D`.

# %%
tf.keras.backend.clear_session()

########## Your Code goes here #############

# TODO: Create the model
model = 

# TODO: Create the optimizer
opt = 

# TODO: Create the loss function
loss = 

# TODO: Create a binary accuracy metric
metrics = 

# TODO: Compile the model


#############################################

# %%
########## Your Code goes here #############

# Train the model
history = 

#############################################

# %% [markdown]
# Compare your results with your results from exercise 2.
